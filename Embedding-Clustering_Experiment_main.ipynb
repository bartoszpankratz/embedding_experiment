# %%
using Distributed
#addprocs(Sys.CPU_THREADS - 2) 
addprocs(4)
# Out:
# 4-element Vector{Int64}:
#  2
#  3
#  4
#  5

# %%
@everywhere begin 
    using Base.Iterators
    using Random
    using ABCDGraphGenerator
    using StatsBase
    using LinearAlgebra
    using Logging
    using PyCall
    using Clustering
    
    #auxilliary function - HOPE embedding:
    function Hope(g, sim, dim, fn; beta=0.01, alpha=0.5)
        dim = dim*2
        A = g.get_adjacency().data
        n = g.vcount()
        ## Katz
        if sim == :katz
            M_g = I - beta * A
            M_l = beta * A
        end
        ## Adamic-Adar
        if sim == :aa
            M_g = I
            D = diagm((x -> x > 1 ? 1/log(x) : 0.0).(g.degree()))
            M_l = A*D*A
            M_l[diagind(M_l)] .= 0.0
        end
        ## Common neighbors
        if sim == :cn
            M_g = I
            M_l = A*A
        end
        ## personalized page rank
        if sim == :ppr
            P = mapslices(A, dims=1) do x
                s = sum(x)
                iszero(s) ? fill(1/n, n) : x / s
            end
            M_g = I-alpha*P
            M_l = (1-alpha)*I
        end
        S = M_g \ M_l
        k = div(dim, 2)
        u, s, vt = svd(S)
        X1 = u[:, 1:k] * diagm(sqrt.(s[1:k]))
        ## undirected graphs have identical source and target embeddings
        if !g.is_directed()
            X = X1
        else
            X2 = vt[:, 1:k] * diagm(sqrt.(s[1:k]))
            X = [X1 X2]
        end


        open(fn, "w") do f
            println(f, size(X,1), " ", size(X, 2))
            for i in axes(X, 1)
                print(f, i, " ")
                for j in axes(X, 2)
                    print(f, X[i, j])
                     j < size(X, 2) && print(f, " ")
                end
                println(f)
            end
        end

    end
    

    #General Parameters:
    no_iters = 30
    seed = 1442
    Random.seed!(seed)
    
    #Paths:
    coms_dir = "experiment/coms/"
    degs_dir = "experiment/degs/"
    graphs_dir = "experiment/graphs/"
    embeds_dir = "experiment/embeddings/"
    res_dir = "experiment/results/"
    logs_dir = "experiment/logs/"
    julia_path = "julia-1.7.2/bin/julia"

    mkpath("experiment")
    mkpath(coms_dir)
    mkpath(degs_dir)
    mkpath(graphs_dir)
    mkpath(embeds_dir)
    mkpath(res_dir)
    mkpath(logs_dir);
        
    #Graph Parameters:
    #ns = [10^3, 10^4,10^6]
    ns = 10^3
    #ξs = range(0.0, 1.0, step = 0.05)
    #ξs = [0.25, 0.5, 0.75]
    ξs  = 0.5
    βs = [1.1, 1.5, 1.9]
    #βs = 1.5
    γs = [2.1, 2.5, 2.9]
    #γs = 2.5
    isCL = false        
    #min_deg = [1,2,5]
    min_deg = 5
    is_local = false
    
    graph_params = sort(reshape(collect(product(ns,ξs,βs,γs,isCL,min_deg,is_local)),:));
    
    #Embeddings parameters:
    dims = 2 .^ collect(3:Int(ceil(log(2,Int(ceil(0.2 *ns))))))


    #deepwalk/node2vec parameters:
    no_walks = 10
    #no_walks = [5,10,20]
    walk_length = 100
    window_size = 10
    ps = [0.25, 0.50, 1., 2., 4.]
    #ps = [0.25, 1.0, 4.0]
    #qs = [0.25, 1.0, 4.0]
    qs = [0.25, 0.50, 1., 2., 4.];


    #LINE parameters:
    negative_ratios = 5

    #SDNE parameters:
    sdne_betas = collect(2:1:10);

    #GraRep parameters:
    grarep_k = [1,2,4,8]

    #HOPE parameters:
    sim_meausures = [:katz,:ppr, :cn, :aa]
    
end

# %%
@distributed for (n, ξ, β, γ, isCL, min_deg, is_local) in graph_params
    @info "Worker $(myid()) start working on parameters $(n) $(ξ) $(γ) $(β) $(min_deg)"
    
    #set params:
    c_min = Int(ceil(0.005*n))               
    c_max = Int(ceil(0.2*n)) 
    max_deg = Int(ceil(sqrt(n)))
    
    #import Python packages: Igraph and Leiden algorithm:
    ig = pyimport("igraph");
    la = pyimport("leidenalg");
    
    #check if graph already exist:
    g_name = graphs_dir * "g_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg).dat"
    g_cl_name = graphs_dir * "g_clusters_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg).dat"
    logname = logs_dir * "g_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg).dat"
    if !isfile(g_name)
        #sample degree sequence:
        deg_filename = degs_dir * "deg_$(n)_$(min_deg)_$(max_deg)_$(γ).dat"
        if !isfile(deg_filename)
            degs = ABCDGraphGenerator.sample_degrees(γ, min_deg, max_deg, n, 1)
            open(io -> foreach(d -> println(io, d), degs), deg_filename, "w")
        else
                degs = parse.(Int,readlines(deg_filename))
        end
    
        #sample communities:
        com_filename = coms_dir * "com_$(n)_$(c_min)_$(c_max)_$(β).dat"
        if !isfile(com_filename)
            coms = ABCDGraphGenerator.sample_communities(β, c_min, c_max, n, 1)
            open(io -> foreach(d -> println(io, d), coms), com_filename, "w")
        else
            coms = parse.(Int,readlines(com_filename))
        end
        
        #generate graph:
        try
            p = ABCDGraphGenerator.ABCDParams(degs, coms, nothing, ξ, isCL, is_local)
            edges, clusters = ABCDGraphGenerator.gen_graph(p)
            open(g_name, "w") do io
                for (a, b) in sort!(collect(edges))
                    println(io, a, "\t", b)
                end
            end
            open(g_cl_name, "w") do io
                for (i, c) in enumerate(clusters)
                    println(io, i, "\t", c)
                end   
            end
       catch err 
            logger = SimpleLogger(open(logname, "w+"))
            with_logger(logger) do
                @warn "graph generation error:"
                @warn exception = (err, stacktrace()), 
                "for params: $(n) $(ξ) $(γ) $(β) $(min_deg)"
            end
        end
    end
    #calculate baseline stats:
    try 
        #read graph (if exist):
        G = ig.Graph.Read_Edgelist(g_name, directed = false)
        G.delete_vertices(0)
        partition = [parse.(Int,e2) - 1 for (e1,e2) in split.(readlines(g_cl_name))]
        
        #find partitions:
        no_partitions = length(unique(partition))
        louvain_partition = G.community_multilevel()
        louvain_length = length(unique(louvain_partition.membership))
        leiden_partition = la.find_partition(G, la.ModularityVertexPartition, seed = seed)
        leiden_length = length(unique(leiden_partition.membership))
        ami_gt_louvain = mutualinfo(partition,louvain_partition.membership)
        ami_gt_leiden = mutualinfo(partition,leiden_partition.membership)
        ami_leiden_louvain = mutualinfo(leiden_partition.membership,louvain_partition.membership)
        #find modularity:
        ground_truth_modularity = G.modularity(partition)
        louvain_modularity = G.modularity(louvain_partition.membership)
        leiden_modularity = G.modularity(leiden_partition.membership)
        
        #save to the file:
        stats_name = res_dir * "g_stats_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg).dat"
        open(stats_name, "w") do io
            println(io, join([n,ξ,γ,β,min_deg,no_partitions,louvain_length,
                        leiden_length,ground_truth_modularity,louvain_modularity, leiden_modularity,ami_gt_louvain,
                        ami_gt_leiden, ami_leiden_louvain],";"))
        end
        
    catch err
        logger = SimpleLogger(open(logname, "w+"))
        with_logger(logger) do
            @warn "cannot calculate stats:"
            @warn exception = (err, stacktrace()), 
            "for params: $(n) $(ξ) $(γ) $(β) $(min_deg)"
        end
    end
    #time for embeddings: 
    # Locally Linear Embedding:
    for dim in dims
        try
            output_name = embeds_dir * "LLE_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg)_$(dim).dat"
            cmd = `python -m openne --method lle --input $(g_name) --graph-format edgelist 
            --output $(output_name) --representation-size $(dim)`
            run(cmd)
            cmd = `$(julia_path) run_clustering.jl $(output_name) $(g_name) $(g_cl_name) $(res_dir) $(seed)`
            run(cmd)
        catch err
            logger = SimpleLogger(open(logname, "w+"))
            with_logger(logger) do
                @warn "LLE embedding error:"
                @warn exception = (err, stacktrace()), 
                "for params: $(n) $(ξ) $(γ) $(β) $(min_deg)"
            end
        end
    end
    
    # Laplacian Eigenmaps:
    for dim in dims
        try
            output_name = embeds_dir * "LE_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg)_$(dim).dat"
            cmd = `python -m openne --method lap --input $(g_name) --graph-format edgelist 
            --output $(output_name) --representation-size $(dim)`
            run(cmd)
            cmd = `$(julia_path) run_clustering.jl $(output_name) $(g_name) $(g_cl_name) $(res_dir) $(seed)`
            run(cmd)
        catch err
            logger = SimpleLogger(open(logname, "w+"))
            with_logger(logger) do
                @warn "LE embedding error:"
                @warn exception = (err, stacktrace()), 
                "for params: $(n) $(ξ) $(γ) $(β) $(min_deg)"
            end
        end
    end

    #deepWalk:
    for (dim, walks, ℓ, window) in sort(reshape(collect(product(dims,no_walks,walk_length,window_size)),:))
      try
            output_name = embeds_dir * "deepWalk_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg)_$(dim).dat"
            cmd = `python -m openne --method deepWalk --input $(g_name) --graph-format edgelist 
            --output $(output_name) --representation-size $(dim) --number-walks $(walks) --walk-length $(ℓ)
            --window-size $(window)`
            run(cmd)
            cmd = `$(julia_path) run_clustering.jl $(output_name) $(g_name) $(g_cl_name) $(res_dir) $(seed)`
            run(cmd)
        catch err
            logger = SimpleLogger(open(logname, "w+"))
            with_logger(logger) do
                @warn "DeepWalk embedding error:"
                @warn exception = (err, stacktrace()), 
                "for params: $(n) $(ξ) $(γ) $(β) $(min_deg)"
            end
        end
    end
    
    #node2vec:
    for (dim, walks, ℓ, window, p, q) in sort(reshape(collect(product(dims,no_walks,walk_length,window_size,ps,qs)),:));
      try
            output_name = embeds_dir * "node2vec_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg)_$(dim)_$(p)_$(q).dat"
            cmd = `python -m openne --method node2vec --input $(g_name) --graph-format edgelist 
            --output $(output_name) --representation-size $(dim) --number-walks $(walks) --walk-length $(ℓ)
            --window-size $(window) --q $(q) --p $(p)`
            run(cmd)
            cmd = `$(julia_path) run_clustering.jl $(output_name) $(g_name) $(g_cl_name) $(res_dir) $(seed)`
            run(cmd)
        catch err
            logger = SimpleLogger(open(logname, "w+"))
            with_logger(logger) do
                @warn "node2vec embedding error:"
                @warn exception = (err, stacktrace()), 
                "for params: $(n) $(ξ) $(γ) $(β) $(min_deg)"
            end
        end
    end

    #LINE:
    for (dim, negative_ratio) in sort(reshape(collect(product(dims,negative_ratios)),:));
      try
            output_name = embeds_dir * "LINE_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg)_$(dim).dat"
            cmd = `python -m openne --method line --input $(g_name) --graph-format edgelist 
            --output $(output_name) --representation-size $(dim) --negative-ratio $(negative_ratio)`
            run(cmd)
            cmd = `$(julia_path) run_clustering.jl $(output_name) $(g_name) $(g_cl_name) $(res_dir) $(seed)`
            run(cmd)
        catch err
            logger = SimpleLogger(open(logname, "w+"))
            with_logger(logger) do
                @warn "LINE embedding error:"
                @warn exception = (err, stacktrace()), 
                "for params: $(n) $(ξ) $(γ) $(β) $(min_deg)"
            end
        end
    end

    #SDNE:
    for (dim, beta) in sort(reshape(collect(product(dims,sdne_betas)),:));
        for ℓ in 2 .^ collect(Int(ceil(log(2,Int(ceil(0.125 *ns))))):Int(ceil(log(2,Int(ceil(0.5 *ns))))))
            ℓ ≤ dim && continue 
            encoder_list = "[$ℓ,$dim]"
            try
                output_name = embeds_dir * "SDNE_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg)_$(dim)_$(ℓ)_$(beta).dat"
                cmd = `python -m openne --method sdne --input $(g_name) --graph-format edgelist 
                --output $(output_name) --representation-size $(dim) --encoder-list $(encoder_list) --beta $(beta)`
                run(cmd)
                cmd = `$(julia_path) run_clustering.jl $(output_name) $(g_name) $(g_cl_name) $(res_dir) $(seed)`
                run(cmd)
            catch err
                logger = SimpleLogger(open(logname, "w+"))
                with_logger(logger) do
                    @warn "SDNE embedding error:"
                    @warn exception = (err, stacktrace()), 
                    "for params: $(n) $(ξ) $(γ) $(β) $(min_deg)"
                end
            end
        end
    end

    #GraRep:
    for (dim,k) in sort(reshape(collect(product(dims,grarep_k)),:));
        try
            output_name = embeds_dir * "GraRep_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg)_$(dim)_$(k).dat"
            cmd = `python -m openne --method grarep --input $(g_name) --graph-format edgelist 
                --output $(output_name) --representation-size $(dim) --kstep $(k)`
            run(cmd)
            cmd = `$(julia_path) run_clustering.jl $(output_name) $(g_name) $(g_cl_name) $(res_dir) $(seed)`
            run(cmd)
        catch err
            logger = SimpleLogger(open(logname, "w+"))
            with_logger(logger) do
                @warn "GraRep embedding error:"
                @warn exception = (err, stacktrace()), 
                "for params: $(n) $(ξ) $(γ) $(β) $(min_deg)"
            end
        end
        
    end

    #HOPE:
    for (dim,sim) in sort(reshape(collect(product(dims,sim_meausures)),:));
        try
            G = ig.Graph.Read_Edgelist(g_name, directed = false)
            G.delete_vertices(0)
            output_name = embeds_dir * "HOPE_$(n)_$(ξ)_$(γ)_$(β)_$(min_deg)_$(dim)_$(sim).dat"
            Hope(G, sim, dim, output_name)
            cmd = `$(julia_path) run_clustering.jl $(output_name) $(g_name) $(g_cl_name) $(res_dir) $(seed)`
            run(cmd)
        catch err
            logger = SimpleLogger(open(logname, "w+"))
            with_logger(logger) do
                @warn "HOPE embedding error:"
                @warn exception = (err, stacktrace()), 
                "for params: $(n) $(ξ) $(γ) $(β) $(min_deg)"
            end
        end
        
    end

    @info "Worker $(myid()) finished working on parameters $(n) $(ξ) $(γ) $(β) $(min_deg)"
end
# Out:
# Task (runnable) @0x00007fbd5ed83de0
#       From worker 3:	[ Info: Worker 3 start working on parameters 1000 0.5 2.1 1.5 5
#       From worker 2:	[ Info: Worker 2 start working on parameters 1000 0.5 2.1 1.1 5
#       From worker 5:	[ Info: Worker 5 start working on parameters 1000 0.5 2.5 1.9 5
#       From worker 4:	[ Info: Worker 4 start working on parameters 1000 0.5 2.9 1.5 5
#       From worker 3:	Reading...
#       From worker 3:	  (0, 0)	1.0
#       From worker 3:	  (0, 1)	-0.03125
#       From worker 3:	  (0, 2)	-0.03125
#       From worker 3:	  (0, 3)	-0.03125
#       From worker 3:	  (0, 4)	-0.03125
#       From worker 3:	  (0, 5)	-0.03125
#       From worker 3:	  (0, 6)	-0.03125
#       From worker 3:	  (0, 7)	-0.03125
#       From worker 3:	  (0, 8)	-0.03125
#       From worker 3:	  (0, 9)	-0.03125
#       From worker 3:	  (0, 10)	-0.03125
#       From worker 3:	  (0, 11)	-0.03125
#       From worker 3:	  (0, 12)	-0.03125
#       From worker 3:	  (0, 13)	-0.03125
#       From worker 3:	  (0, 14)	-0.03125
#       From worker 3:	  (0, 15)	-0.03125
#       From worker 3:	  (0, 16)	-0.03125
#       From worker 3:	  (0, 17)	-0.03125
#       From worker 3:	  (0, 18)	-0.03125
#       From worker 3:	  (0, 19)	-0.03125
#       From worker 3:	  (0, 20)	-0.03125
#       From worker 3:	  (0, 21)	-0.03125
#       From worker 3:	  (0, 22)	-0.03125
#       From worker 3:	  (0, 23)	-0.03125
#       From worker 3:	  (0, 24)	-0.03125
#       From worker 3:	  :	:
#       From worker 3:	  (995, 995)	1.0
#       From worker 3:	  (996, 166)	-0.2
#       From worker 3:	  (996, 172)	-0.2
#       From worker 3:	  (996, 264)	-0.2
#       From worker 3:	  (996, 707)	-0.2
#       From worker 3:	  (996, 905)	-0.2
#       From worker 3:	  (996, 996)	1.0
#       From worker 3:	  (997, 195)	-0.2
#       From worker 3:	  (997, 640)	-0.2
#       From worker 3:	  (997, 686)	-0.2
#       From worker 3:	  (997, 864)	-0.2
#       From worker 3:	  (997, 877)	-0.2
#       From worker 3:	  (997, 997)	1.0
#       From worker 3:	  (998, 515)	-0.2
#       From worker 3:	  (998, 694)	-0.2
#       From worker 3:	  (998, 706)	-0.2
#       From worker 3:	  (998, 825)	-0.2
#       From worker 3:	  (998, 889)	-0.2
#       From worker 3:	  (998, 998)	1.0
#       From worker 3:	  (999, 305)	-0.2
#       From worker 3:	  (999, 456)	-0.2
#       From worker 3:	  (999, 657)	-0.2
#       From worker 3:	  (999, 697)	-0.2
#       From worker 3:	  (999, 806)	-0.2
#       From worker 3:	  (999, 999)	1.0
#       From worker 3:	0.10377311706542969
#       From worker 3:	Saving embeddings...
#       From worker 5:	Reading...
#       From worker 5:	  (0, 0)	1.0
#       From worker 5:	  (0, 1)	-0.03125
#       From worker 5:	  (0, 2)	-0.03125
#       From worker 5:	  (0, 3)	-0.03125
#       From worker 5:	  (0, 4)	-0.03125
#       From worker 5:	  (0, 5)	-0.03125
#       From worker 5:	  (0, 6)	-0.03125
#       From worker 5:	  (0, 7)	-0.03125
#       From worker 5:	  (0, 8)	-0.03125
#       From worker 5:	  (0, 9)	-0.03125
#       From worker 5:	  (0, 10)	-0.03125
#       From worker 5:	  (0, 11)	-0.03125
#       From worker 5:	  (0, 12)	-0.03125
#       From worker 5:	  (0, 13)	-0.03125
#       From worker 5:	  (0, 14)	-0.03125
#       From worker 5:	  (0, 15)	-0.03125
#       From worker 5:	  (0, 16)	-0.03125
#       From worker 5:	  (0, 17)	-0.03125
#       From worker 5:	  (0, 18)	-0.03125
#       From worker 5:	  (0, 19)	-0.03125
#       From worker 5:	  (0, 20)	-0.03125
#       From worker 5:	  (0, 21)	-0.03125
#       From worker 5:	  (0, 22)	-0.03125
#       From worker 5:	  (0, 23)	-0.03125
#       From worker 5:	  (0, 24)	-0.03125
#       From worker 5:	  :	:
#       From worker 5:	  (996, 663)	-0.2
#       From worker 5:	  (996, 913)	-0.2
#       From worker 5:	  (996, 996)	1.0
#       From worker 5:	  (997, 88)	-0.14285714285714285
#       From worker 5:	  (997, 278)	-0.14285714285714285
#       From worker 5:	  (997, 452)	-0.14285714285714285
#       From worker 5:	  (997, 555)	-0.14285714285714285
#       From worker 5:	  (997, 625)	-0.14285714285714285
#       From worker 5:	  (997, 823)	-0.14285714285714285
#       From worker 5:	  (997, 828)	-0.14285714285714285
#       From worker 5:	  (997, 997)	1.0
#       From worker 5:	  (998, 343)	-0.2
#       From worker 5:	  (998, 759)	-0.2
#       From worker 5:	  (998, 839)	-0.2
#       From worker 5:	  (998, 872)	-0.2
#       From worker 5:	  (998, 946)	-0.2
#       From worker 5:	  (998, 998)	1.0
#       From worker 5:	  (999, 195)	-0.14285714285714285
#       From worker 5:	  (999, 260)	-0.14285714285714285
#       From worker 5:	  (999, 620)	-0.14285714285714285
#       From worker 5:	  (999, 691)	-0.14285714285714285
#       From worker 5:	  (999, 726)	-0.14285714285714285
#       From worker 5:	  (999, 741)	-0.14285714285714285
#       From worker 5:	  (999, 941)	-0.14285714285714285
#       From worker 5:	  (999, 999)	1.0
#       From worker 5:	0.09355354309082031
#       From worker 5:	Saving embeddings...
#       From worker 2:	Reading...
#       From worker 2:	  (0, 0)	1.0
#       From worker 2:	  (0, 1)	-0.03125
#       From worker 2:	  (0, 2)	-0.03125
#       From worker 2:	  (0, 3)	-0.03125
#       From worker 2:	  (0, 4)	-0.03125
#       From worker 2:	  (0, 5)	-0.03125
#       From worker 2:	  (0, 6)	-0.03125
#       From worker 2:	  (0, 7)	-0.03125
#       From worker 2:	  (0, 8)	-0.03125
#       From worker 2:	  (0, 9)	-0.03125
#       From worker 2:	  (0, 10)	-0.03125
#       From worker 2:	  (0, 11)	-0.03125
#       From worker 2:	  (0, 12)	-0.03125
#       From worker 2:	  (0, 13)	-0.03125
#       From worker 2:	  (0, 14)	-0.03125
#       From worker 2:	  (0, 15)	-0.03125
#       From worker 2:	  (0, 16)	-0.03125
#       From worker 2:	  (0, 17)	-0.03125
#       From worker 2:	  (0, 18)	-0.03125
#       From worker 2:	  (0, 19)	-0.03125
#       From worker 2:	  (0, 20)	-0.03125
#       From worker 2:	  (0, 21)	-0.03125
#       From worker 2:	  (0, 22)	-0.03125
#       From worker 2:	  (0, 23)	-0.03125
#       From worker 2:	  (0, 24)	-0.03125
#       From worker 2:	  :	:
#       From worker 2:	  (996, 978)	-0.16666666666666666
#       From worker 2:	  (996, 992)	-0.16666666666666666
#       From worker 2:	  (996, 996)	1.0
#       From worker 2:	  (997, 249)	-0.14285714285714285
#       From worker 2:	  (997, 457)	-0.14285714285714285
#       From worker 2:	  (997, 526)	-0.14285714285714285
#       From worker 2:	  (997, 611)	-0.14285714285714285
#       From worker 2:	  (997, 744)	-0.14285714285714285
#       From worker 2:	  (997, 811)	-0.14285714285714285
#       From worker 2:	  (997, 968)	-0.14285714285714285
#       From worker 2:	  (997, 997)	1.0
#       From worker 2:	  (998, 417)	-0.14285714285714285
#       From worker 2:	  (998, 595)	-0.14285714285714285
#       From worker 2:	  (998, 825)	-0.14285714285714285
#       From worker 2:	  (998, 831)	-0.14285714285714285
#       From worker 2:	  (998, 852)	-0.14285714285714285
#       From worker 2:	  (998, 878)	-0.14285714285714285
#       From worker 2:	  (998, 988)	-0.14285714285714285
#       From worker 2:	  (998, 998)	1.0
#       From worker 2:	  (999, 628)	-0.2
#       From worker 2:	  (999, 737)	-0.2
#       From worker 2:	  (999, 946)	-0.2
#       From worker 2:	  (999, 957)	-0.2
#       From worker 2:	  (999, 965)	-0.2
#       From worker 2:	  (999, 999)	1.0
#       From worker 2:	0.11597228050231934
#       From worker 2:	Saving embeddings...
#       From worker 4:	Reading...
#       From worker 4:	  (0, 0)	1.0
#       From worker 4:	  (0, 1)	-0.03125
#       From worker 4:	  (0, 2)	-0.03125
#       From worker 4:	  (0, 3)	-0.03125
#       From worker 4:	  (0, 4)	-0.03125
#       From worker 4:	  (0, 5)	-0.03125
#       From worker 4:	  (0, 6)	-0.03125
#       From worker 4:	  (0, 7)	-0.03125
#       From worker 4:	  (0, 8)	-0.03125
#       From worker 4:	  (0, 9)	-0.03125
#       From worker 4:	  (0, 10)	-0.03125
#       From worker 4:	  (0, 11)	-0.03125
#       From worker 4:	  (0, 12)	-0.03125
#       From worker 4:	  (0, 13)	-0.03125
#       From worker 4:	  (0, 14)	-0.03125
#       From worker 4:	  (0, 15)	-0.03125
#       From worker 4:	  (0, 16)	-0.03125
#       From worker 4:	  (0, 17)	-0.03125
#       From worker 4:	  (0, 18)	-0.03125
#       From worker 4:	  (0, 19)	-0.03125
#       From worker 4:	  (0, 20)	-0.03125
#       From worker 4:	  (0, 21)	-0.03125
#       From worker 4:	  (0, 22)	-0.03125
#       From worker 4:	  (0, 23)	-0.03125
#       From worker 4:	  (0, 24)	-0.03125
#       From worker 4:	  :	:
#       From worker 4:	  (996, 433)	-0.2
#       From worker 4:	  (996, 619)	-0.2
#       From worker 4:	  (996, 736)	-0.2
#       From worker 4:	  (996, 776)	-0.2
#       From worker 4:	  (996, 996)	1.0
#       From worker 4:	  (997, 215)	-0.16666666666666666
#       From worker 4:	  (997, 342)	-0.16666666666666666
#       From worker 4:	  (997, 640)	-0.16666666666666666
#       From worker 4:	  (997, 644)	-0.16666666666666666
#       From worker 4:	  (997, 752)	-0.16666666666666666
#       From worker 4:	  (997, 827)	-0.16666666666666666
#       From worker 4:	  (997, 997)	1.0
#       From worker 4:	  (998, 258)	-0.16666666666666666
#       From worker 4:	  (998, 343)	-0.16666666666666666
#       From worker 4:	  (998, 632)	-0.16666666666666666
#       From worker 4:	  (998, 887)	-0.16666666666666666
#       From worker 4:	  (998, 900)	-0.16666666666666666
#       From worker 4:	  (998, 992)	-0.16666666666666666
#       From worker 4:	  (998, 998)	1.0
#       From worker 4:	  (999, 252)	-0.2
#       From worker 4:	  (999, 376)	-0.2
#       From worker 4:	  (999, 432)	-0.2
#       From worker 4:	  (999, 658)	-0.2
#       From worker 4:	  (999, 893)	-0.2
#       From worker 4:	  (999, 999)	1.0
#       From worker 4:	0.1406397819519043
#       From worker 4:	Saving embeddings...
#       From worker 5:	........................................
#       From worker 3:	........................................
#       From worker 2:	........................................
#       From worker 4:	........................................
#       From worker 5:	Reading...
#       From worker 5:	  (0, 0)	1.0
#       From worker 5:	  (0, 1)	-0.03125
#       From worker 5:	  (0, 2)	-0.03125
#       From worker 5:	  (0, 3)	-0.03125
#       From worker 5:	  (0, 4)	-0.03125
#       From worker 5:	  (0, 5)	-0.03125
#       From worker 5:	  (0, 6)	-0.03125
#       From worker 5:	  (0, 7)	-0.03125
#       From worker 5:	  (0, 8)	-0.03125
#       From worker 5:	  (0, 9)	-0.03125
#       From worker 5:	  (0, 10)	-0.03125
#       From worker 5:	  (0, 11)	-0.03125
#       From worker 5:	  (0, 12)	-0.03125
#       From worker 5:	  (0, 13)	-0.03125
#       From worker 5:	  (0, 14)	-0.03125
#       From worker 5:	  (0, 15)	-0.03125
#       From worker 5:	  (0, 16)	-0.03125
#       From worker 5:	  (0, 17)	-0.03125
#       From worker 5:	  (0, 18)	-0.03125
#       From worker 5:	  (0, 19)	-0.03125
#       From worker 5:	  (0, 20)	-0.03125
#       From worker 5:	  (0, 21)	-0.03125
#       From worker 5:	  (0, 22)	-0.03125
#       From worker 5:	  (0, 23)	-0.03125
#       From worker 5:	  (0, 24)	-0.03125
#       From worker 5:	  :	:
#       From worker 5:	  (996, 663)	-0.2
#       From worker 5:	  (996, 913)	-0.2
#       From worker 5:	  (996, 996)	1.0
#       From worker 5:	  (997, 88)	-0.14285714285714285
#       From worker 5:	  (997, 278)	-0.14285714285714285
#       From worker 5:	  (997, 452)	-0.14285714285714285
#       From worker 5:	  (997, 555)	-0.14285714285714285
#       From worker 5:	  (997, 625)	-0.14285714285714285
#       From worker 5:	  (997, 823)	-0.14285714285714285
#       From worker 5:	  (997, 828)	-0.14285714285714285
#       From worker 5:	  (997, 997)	1.0
#       From worker 5:	  (998, 343)	-0.2
#       From worker 5:	  (998, 759)	-0.2
#       From worker 5:	  (998, 839)	-0.2
#       From worker 5:	  (998, 872)	-0.2
#       From worker 5:	  (998, 946)	-0.2
#       From worker 5:	  (998, 998)	1.0
#       From worker 5:	  (999, 195)	-0.14285714285714285
#       From worker 5:	  (999, 260)	-0.14285714285714285
#       From worker 5:	  (999, 620)	-0.14285714285714285
#       From worker 5:	  (999, 691)	-0.14285714285714285
#       From worker 5:	  (999, 726)	-0.14285714285714285
#       From worker 5:	  (999, 741)	-0.14285714285714285
#       From worker 5:	  (999, 941)	-0.14285714285714285
#       From worker 5:	  (999, 999)	1.0
#       From worker 5:	0.21819186210632324
#       From worker 5:	Saving embeddings...
#       From worker 2:	Reading...
#       From worker 2:	  (0, 0)	1.0
#       From worker 2:	  (0, 1)	-0.03125
#       From worker 2:	  (0, 2)	-0.03125
#       From worker 2:	  (0, 3)	-0.03125
#       From worker 2:	  (0, 4)	-0.03125
#       From worker 2:	  (0, 5)	-0.03125
#       From worker 2:	  (0, 6)	-0.03125
#       From worker 2:	  (0, 7)	-0.03125
#       From worker 2:	  (0, 8)	-0.03125
#       From worker 2:	  (0, 9)	-0.03125
#       From worker 2:	  (0, 10)	-0.03125
#       From worker 2:	  (0, 11)	-0.03125
#       From worker 2:	  (0, 12)	-0.03125
#       From worker 2:	  (0, 13)	-0.03125
#       From worker 2:	  (0, 14)	-0.03125
#       From worker 2:	  (0, 15)	-0.03125
#       From worker 2:	  (0, 16)	-0.03125
#       From worker 2:	  (0, 17)	-0.03125
#       From worker 2:	  (0, 18)	-0.03125
#       From worker 2:	  (0, 19)	-0.03125
#       From worker 2:	  (0, 20)	-0.03125
#       From worker 2:	  (0, 21)	-0.03125
#       From worker 2:	  (0, 22)	-0.03125
#       From worker 2:	  (0, 23)	-0.03125
#       From worker 2:	  (0, 24)	-0.03125
#       From worker 2:	  :	:
#       From worker 2:	  (996, 978)	-0.16666666666666666
#       From worker 2:	  (996, 992)	-0.16666666666666666
#       From worker 2:	  (996, 996)	1.0
#       From worker 2:	  (997, 249)	-0.14285714285714285
#       From worker 2:	  (997, 457)	-0.14285714285714285
#       From worker 2:	  (997, 526)	-0.14285714285714285
#       From worker 2:	  (997, 611)	-0.14285714285714285
#       From worker 2:	  (997, 744)	-0.14285714285714285
#       From worker 2:	  (997, 811)	-0.14285714285714285
#       From worker 2:	  (997, 968)	-0.14285714285714285
#       From worker 2:	  (997, 997)	1.0
#       From worker 2:	  (998, 417)	-0.14285714285714285
#       From worker 2:	  (998, 595)	-0.14285714285714285
#       From worker 2:	  (998, 825)	-0.14285714285714285
#       From worker 2:	  (998, 831)	-0.14285714285714285
#       From worker 2:	  (998, 852)	-0.14285714285714285
#       From worker 2:	  (998, 878)	-0.14285714285714285
#       From worker 2:	  (998, 988)	-0.14285714285714285
#       From worker 2:	  (998, 998)	1.0
#       From worker 2:	  (999, 628)	-0.2
#       From worker 2:	  (999, 737)	-0.2
#       From worker 2:	  (999, 946)	-0.2
#       From worker 2:	  (999, 957)	-0.2
#       From worker 2:	  (999, 965)	-0.2
#       From worker 2:	  (999, 999)	1.0
#       From worker 2:	0.1636040210723877
#       From worker 2:	Saving embeddings...
#       From worker 4:	/root/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/eigen/arpack/arpack.py:1849: RuntimeWarning: invalid value encountered in sqrt
#       From worker 4:	  s = np.sqrt(eigvals)
#       From worker 4:	Reading...
#       From worker 4:	  (0, 0)	1.0
#       From worker 4:	  (0, 1)	-0.03125
#       From worker 4:	  (0, 2)	-0.03125
#       From worker 4:	  (0, 3)	-0.03125
#       From worker 4:	  (0, 4)	-0.03125
#       From worker 4:	  (0, 5)	-0.03125
#       From worker 4:	  (0, 6)	-0.03125
#       From worker 4:	  (0, 7)	-0.03125
#       From worker 4:	  (0, 8)	-0.03125
#       From worker 4:	  (0, 9)	-0.03125
#       From worker 4:	  (0, 10)	-0.03125
#       From worker 4:	  (0, 11)	-0.03125
#       From worker 4:	  (0, 12)	-0.03125
#       From worker 4:	  (0, 13)	-0.03125
#       From worker 4:	  (0, 14)	-0.03125
#       From worker 4:	  (0, 15)	-0.03125
#       From worker 4:	  (0, 16)	-0.03125
#       From worker 4:	  (0, 17)	-0.03125
#       From worker 4:	  (0, 18)	-0.03125
#       From worker 4:	  (0, 19)	-0.03125
#       From worker 4:	  (0, 20)	-0.03125
#       From worker 4:	  (0, 21)	-0.03125
#       From worker 4:	  (0, 22)	-0.03125
#       From worker 4:	  (0, 23)	-0.03125
#       From worker 4:	  (0, 24)	-0.03125
#       From worker 4:	  :	:
#       From worker 4:	  (996, 433)	-0.2
#       From worker 4:	  (996, 619)	-0.2
#       From worker 4:	  (996, 736)	-0.2
#       From worker 4:	  (996, 776)	-0.2
#       From worker 4:	  (996, 996)	1.0
#       From worker 4:	  (997, 215)	-0.16666666666666666
#       From worker 4:	  (997, 342)	-0.16666666666666666
#       From worker 4:	  (997, 640)	-0.16666666666666666
#       From worker 4:	  (997, 644)	-0.16666666666666666
#       From worker 4:	  (997, 752)	-0.16666666666666666
#       From worker 4:	  (997, 827)	-0.16666666666666666
#       From worker 4:	  (997, 997)	1.0
#       From worker 4:	  (998, 258)	-0.16666666666666666
#       From worker 4:	  (998, 343)	-0.16666666666666666
#       From worker 4:	  (998, 632)	-0.16666666666666666
#       From worker 4:	  (998, 887)	-0.16666666666666666
#       From worker 4:	  (998, 900)	-0.16666666666666666
#       From worker 4:	  (998, 992)	-0.16666666666666666
#       From worker 4:	  (998, 998)	1.0
#       From worker 4:	  (999, 252)	-0.2
#       From worker 4:	  (999, 376)	-0.2
#       From worker 4:	  (999, 432)	-0.2
#       From worker 4:	  (999, 658)	-0.2
#       From worker 4:	  (999, 893)	-0.2
#       From worker 4:	  (999, 999)	1.0
#       From worker 4:	0.20296359062194824
#       From worker 4:	Saving embeddings...
#       From worker 3:	Reading...
#       From worker 3:	  (0, 0)	1.0
#       From worker 3:	  (0, 1)	-0.03125
#       From worker 3:	  (0, 2)	-0.03125
#       From worker 3:	  (0, 3)	-0.03125
#       From worker 3:	  (0, 4)	-0.03125
#       From worker 3:	  (0, 5)	-0.03125
#       From worker 3:	  (0, 6)	-0.03125
#       From worker 3:	  (0, 7)	-0.03125
#       From worker 3:	  (0, 8)	-0.03125
#       From worker 3:	  (0, 9)	-0.03125
#       From worker 3:	  (0, 10)	-0.03125
#       From worker 3:	  (0, 11)	-0.03125
#       From worker 3:	  (0, 12)	-0.03125
#       From worker 3:	  (0, 13)	-0.03125
#       From worker 3:	  (0, 14)	-0.03125
#       From worker 3:	  (0, 15)	-0.03125
#       From worker 3:	  (0, 16)	-0.03125
#       From worker 3:	  (0, 17)	-0.03125
#       From worker 3:	  (0, 18)	-0.03125
#       From worker 3:	  (0, 19)	-0.03125
#       From worker 3:	  (0, 20)	-0.03125
#       From worker 3:	  (0, 21)	-0.03125
#       From worker 3:	  (0, 22)	-0.03125
#       From worker 3:	  (0, 23)	-0.03125
#       From worker 3:	  (0, 24)	-0.03125
#       From worker 3:	  :	:
#       From worker 3:	  (995, 995)	1.0
#       From worker 3:	  (996, 166)	-0.2
#       From worker 3:	  (996, 172)	-0.2
#       From worker 3:	  (996, 264)	-0.2
#       From worker 3:	  (996, 707)	-0.2
#       From worker 3:	  (996, 905)	-0.2
#       From worker 3:	  (996, 996)	1.0
#       From worker 3:	  (997, 195)	-0.2
#       From worker 3:	  (997, 640)	-0.2
#       From worker 3:	  (997, 686)	-0.2
#       From worker 3:	  (997, 864)	-0.2
#       From worker 3:	  (997, 877)	-0.2
#       From worker 3:	  (997, 997)	1.0
#       From worker 3:	  (998, 515)	-0.2
#       From worker 3:	  (998, 694)	-0.2
#       From worker 3:	  (998, 706)	-0.2
#       From worker 3:	  (998, 825)	-0.2
#       From worker 3:	  (998, 889)	-0.2
#       From worker 3:	  (998, 998)	1.0
#       From worker 3:	  (999, 305)	-0.2
#       From worker 3:	  (999, 456)	-0.2
#       From worker 3:	  (999, 657)	-0.2
#       From worker 3:	  (999, 697)	-0.2
#       From worker 3:	  (999, 806)	-0.2
#       From worker 3:	  (999, 999)	1.0
#       From worker 3:	0.1505742073059082
#       From worker 3:	Saving embeddings...
#       From worker 5:	........................................
#       From worker 2:	........................................
#       From worker 4:	........................................
#       From worker 3:	........................................
#       From worker 5:	/root/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/eigen/arpack/arpack.py:1849: RuntimeWarning: invalid value encountered in sqrt
#       From worker 5:	  s = np.sqrt(eigvals)
#       From worker 5:	Reading...
#       From worker 5:	  (0, 0)	1.0
#       From worker 5:	  (0, 1)	-0.03125
#       From worker 5:	  (0, 2)	-0.03125
#       From worker 5:	  (0, 3)	-0.03125
#       From worker 5:	  (0, 4)	-0.03125
#       From worker 5:	  (0, 5)	-0.03125
#       From worker 5:	  (0, 6)	-0.03125
#       From worker 5:	  (0, 7)	-0.03125
#       From worker 5:	  (0, 8)	-0.03125
#       From worker 5:	  (0, 9)	-0.03125
#       From worker 5:	  (0, 10)	-0.03125
#       From worker 5:	  (0, 11)	-0.03125
#       From worker 5:	  (0, 12)	-0.03125
#       From worker 5:	  (0, 13)	-0.03125
#       From worker 5:	  (0, 14)	-0.03125
#       From worker 5:	  (0, 15)	-0.03125
#       From worker 5:	  (0, 16)	-0.03125
#       From worker 5:	  (0, 17)	-0.03125
#       From worker 5:	  (0, 18)	-0.03125
#       From worker 5:	  (0, 19)	-0.03125
#       From worker 5:	  (0, 20)	-0.03125
#       From worker 5:	  (0, 21)	-0.03125
#       From worker 5:	  (0, 22)	-0.03125
#       From worker 5:	  (0, 23)	-0.03125
#       From worker 5:	  (0, 24)	-0.03125
#       From worker 5:	  :	:
#       From worker 5:	  (996, 663)	-0.2
#       From worker 5:	  (996, 913)	-0.2
#       From worker 5:	  (996, 996)	1.0
#       From worker 5:	  (997, 88)	-0.14285714285714285
#       From worker 5:	  (997, 278)	-0.14285714285714285
#       From worker 5:	  (997, 452)	-0.14285714285714285
#       From worker 5:	  (997, 555)	-0.14285714285714285
#       From worker 5:	  (997, 625)	-0.14285714285714285
#       From worker 5:	  (997, 823)	-0.14285714285714285
#       From worker 5:	  (997, 828)	-0.14285714285714285
#       From worker 5:	  (997, 997)	1.0
#       From worker 5:	  (998, 343)	-0.2
#       From worker 5:	  (998, 759)	-0.2
#       From worker 5:	  (998, 839)	-0.2
#       From worker 5:	  (998, 872)	-0.2
#       From worker 5:	  (998, 946)	-0.2
#       From worker 5:	  (998, 998)	1.0
#       From worker 5:	  (999, 195)	-0.14285714285714285
#       From worker 5:	  (999, 260)	-0.14285714285714285
#       From worker 5:	  (999, 620)	-0.14285714285714285
#       From worker 5:	  (999, 691)	-0.14285714285714285
#       From worker 5:	  (999, 726)	-0.14285714285714285
#       From worker 5:	  (999, 741)	-0.14285714285714285
#       From worker 5:	  (999, 941)	-0.14285714285714285
#       From worker 5:	  (999, 999)	1.0
#       From worker 5:	0.4061615467071533
#       From worker 5:	Saving embeddings...
#       From worker 4:	Reading...
#       From worker 4:	  (0, 0)	1.0
#       From worker 4:	  (0, 1)	-0.03125
#       From worker 4:	  (0, 2)	-0.03125
#       From worker 4:	  (0, 3)	-0.03125
#       From worker 4:	  (0, 4)	-0.03125
#       From worker 4:	  (0, 5)	-0.03125
#       From worker 4:	  (0, 6)	-0.03125
#       From worker 4:	  (0, 7)	-0.03125
#       From worker 4:	  (0, 8)	-0.03125
#       From worker 4:	  (0, 9)	-0.03125
#       From worker 4:	  (0, 10)	-0.03125
#       From worker 4:	  (0, 11)	-0.03125
#       From worker 4:	  (0, 12)	-0.03125
#       From worker 4:	  (0, 13)	-0.03125
#       From worker 4:	  (0, 14)	-0.03125
#       From worker 4:	  (0, 15)	-0.03125
#       From worker 4:	  (0, 16)	-0.03125
#       From worker 4:	  (0, 17)	-0.03125
#       From worker 4:	  (0, 18)	-0.03125
#       From worker 4:	  (0, 19)	-0.03125
#       From worker 4:	  (0, 20)	-0.03125
#       From worker 4:	  (0, 21)	-0.03125
#       From worker 4:	  (0, 22)	-0.03125
#       From worker 4:	  (0, 23)	-0.03125
#       From worker 4:	  (0, 24)	-0.03125
#       From worker 4:	  :	:
#       From worker 4:	  (996, 433)	-0.2
#       From worker 4:	  (996, 619)	-0.2
#       From worker 4:	  (996, 736)	-0.2
#       From worker 4:	  (996, 776)	-0.2
#       From worker 4:	  (996, 996)	1.0
#       From worker 4:	  (997, 215)	-0.16666666666666666
#       From worker 4:	  (997, 342)	-0.16666666666666666
#       From worker 4:	  (997, 640)	-0.16666666666666666
#       From worker 4:	  (997, 644)	-0.16666666666666666
#       From worker 4:	  (997, 752)	-0.16666666666666666
#       From worker 4:	  (997, 827)	-0.16666666666666666
#       From worker 4:	  (997, 997)	1.0
#       From worker 4:	  (998, 258)	-0.16666666666666666
#       From worker 4:	  (998, 343)	-0.16666666666666666
#       From worker 4:	  (998, 632)	-0.16666666666666666
#       From worker 4:	  (998, 887)	-0.16666666666666666
#       From worker 4:	  (998, 900)	-0.16666666666666666
#       From worker 4:	  (998, 992)	-0.16666666666666666
#       From worker 4:	  (998, 998)	1.0
#       From worker 4:	  (999, 252)	-0.2
#       From worker 4:	  (999, 376)	-0.2
#       From worker 4:	  (999, 432)	-0.2
#       From worker 4:	  (999, 658)	-0.2
#       From worker 4:	  (999, 893)	-0.2
#       From worker 4:	  (999, 999)	1.0
#       From worker 4:	0.31949591636657715
#       From worker 4:	Saving embeddings...
#       From worker 3:	Reading...
#       From worker 3:	  (0, 0)	1.0
#       From worker 3:	  (0, 1)	-0.03125
#       From worker 3:	  (0, 2)	-0.03125
#       From worker 3:	  (0, 3)	-0.03125
#       From worker 3:	  (0, 4)	-0.03125
#       From worker 3:	  (0, 5)	-0.03125
#       From worker 3:	  (0, 6)	-0.03125
#       From worker 3:	  (0, 7)	-0.03125
#       From worker 3:	  (0, 8)	-0.03125
#       From worker 3:	  (0, 9)	-0.03125
#       From worker 3:	  (0, 10)	-0.03125
#       From worker 3:	  (0, 11)	-0.03125
#       From worker 3:	  (0, 12)	-0.03125
#       From worker 3:	  (0, 13)	-0.03125
#       From worker 3:	  (0, 14)	-0.03125
#       From worker 3:	  (0, 15)	-0.03125
#       From worker 3:	  (0, 16)	-0.03125
#       From worker 3:	  (0, 17)	-0.03125
#       From worker 3:	  (0, 18)	-0.03125
#       From worker 3:	  (0, 19)	-0.03125
#       From worker 3:	  (0, 20)	-0.03125
#       From worker 3:	  (0, 21)	-0.03125
#       From worker 3:	  (0, 22)	-0.03125
#       From worker 3:	  (0, 23)	-0.03125
#       From worker 3:	  (0, 24)	-0.03125
#       From worker 3:	  :	:
#       From worker 3:	  (995, 995)	1.0
#       From worker 3:	  (996, 166)	-0.2
#       From worker 3:	  (996, 172)	-0.2
#       From worker 3:	  (996, 264)	-0.2
#       From worker 3:	  (996, 707)	-0.2
#       From worker 3:	  (996, 905)	-0.2
#       From worker 3:	  (996, 996)	1.0
#       From worker 3:	  (997, 195)	-0.2
#       From worker 3:	  (997, 640)	-0.2
#       From worker 3:	  (997, 686)	-0.2
#       From worker 3:	  (997, 864)	-0.2
#       From worker 3:	  (997, 877)	-0.2
#       From worker 3:	  (997, 997)	1.0
#       From worker 3:	  (998, 515)	-0.2
#       From worker 3:	  (998, 694)	-0.2
#       From worker 3:	  (998, 706)	-0.2
#       From worker 3:	  (998, 825)	-0.2
#       From worker 3:	  (998, 889)	-0.2
#       From worker 3:	  (998, 998)	1.0
#       From worker 3:	  (999, 305)	-0.2
#       From worker 3:	  (999, 456)	-0.2
#       From worker 3:	  (999, 657)	-0.2
#       From worker 3:	  (999, 697)	-0.2
#       From worker 3:	  (999, 806)	-0.2
#       From worker 3:	  (999, 999)	1.0
#       From worker 3:	0.20978713035583496
#       From worker 3:	Saving embeddings...
#       From worker 2:	Reading...
#       From worker 2:	  (0, 0)	1.0
#       From worker 2:	  (0, 1)	-0.03125
#       From worker 2:	  (0, 2)	-0.03125
#       From worker 2:	  (0, 3)	-0.03125
#       From worker 2:	  (0, 4)	-0.03125
#       From worker 2:	  (0, 5)	-0.03125
#       From worker 2:	  (0, 6)	-0.03125
#       From worker 2:	  (0, 7)	-0.03125
#       From worker 2:	  (0, 8)	-0.03125
#       From worker 2:	  (0, 9)	-0.03125
#       From worker 2:	  (0, 10)	-0.03125
#       From worker 2:	  (0, 11)	-0.03125
#       From worker 2:	  (0, 12)	-0.03125
#       From worker 2:	  (0, 13)	-0.03125
#       From worker 2:	  (0, 14)	-0.03125
#       From worker 2:	  (0, 15)	-0.03125
#       From worker 2:	  (0, 16)	-0.03125
#       From worker 2:	  (0, 17)	-0.03125
#       From worker 2:	  (0, 18)	-0.03125
#       From worker 2:	  (0, 19)	-0.03125
#       From worker 2:	  (0, 20)	-0.03125
#       From worker 2:	  (0, 21)	-0.03125
#       From worker 2:	  (0, 22)	-0.03125
#       From worker 2:	  (0, 23)	-0.03125
#       From worker 2:	  (0, 24)	-0.03125
#       From worker 2:	  :	:
#       From worker 2:	  (996, 978)	-0.16666666666666666
#       From worker 2:	  (996, 992)	-0.16666666666666666
#       From worker 2:	  (996, 996)	1.0
#       From worker 2:	  (997, 249)	-0.14285714285714285
#       From worker 2:	  (997, 457)	-0.14285714285714285
#       From worker 2:	  (997, 526)	-0.14285714285714285
#       From worker 2:	  (997, 611)	-0.14285714285714285
#       From worker 2:	  (997, 744)	-0.14285714285714285
#       From worker 2:	  (997, 811)	-0.14285714285714285
#       From worker 2:	  (997, 968)	-0.14285714285714285
#       From worker 2:	  (997, 997)	1.0
#       From worker 2:	  (998, 417)	-0.14285714285714285
#       From worker 2:	  (998, 595)	-0.14285714285714285
#       From worker 2:	  (998, 825)	-0.14285714285714285
#       From worker 2:	  (998, 831)	-0.14285714285714285
#       From worker 2:	  (998, 852)	-0.14285714285714285
#       From worker 2:	  (998, 878)	-0.14285714285714285
#       From worker 2:	  (998, 988)	-0.14285714285714285
#       From worker 2:	  (998, 998)	1.0
#       From worker 2:	  (999, 628)	-0.2
#       From worker 2:	  (999, 737)	-0.2
#       From worker 2:	  (999, 946)	-0.2
#       From worker 2:	  (999, 957)	-0.2
#       From worker 2:	  (999, 965)	-0.2
#       From worker 2:	  (999, 999)	1.0
#       From worker 2:	0.19538426399230957
#       From worker 2:	Saving embeddings...
#       From worker 5:	........................................
#       From worker 4:	........................................
#       From worker 3:	........................................
#       From worker 2:	........................................
#       From worker 5:	Reading...
#       From worker 5:	  (0, 0)	1.0
#       From worker 5:	  (0, 1)	-0.03125
#       From worker 5:	  (0, 2)	-0.03125
#       From worker 5:	  (0, 3)	-0.03125
#       From worker 5:	  (0, 4)	-0.03125
#       From worker 5:	  (0, 5)	-0.03125
#       From worker 5:	  (0, 6)	-0.03125
#       From worker 5:	  (0, 7)	-0.03125
#       From worker 5:	  (0, 8)	-0.03125
#       From worker 5:	  (0, 9)	-0.03125
#       From worker 5:	  (0, 10)	-0.03125
#       From worker 5:	  (0, 11)	-0.03125
#       From worker 5:	  (0, 12)	-0.03125
#       From worker 5:	  (0, 13)	-0.03125
#       From worker 5:	  (0, 14)	-0.03125
#       From worker 5:	  (0, 15)	-0.03125
#       From worker 5:	  (0, 16)	-0.03125
#       From worker 5:	  (0, 17)	-0.03125
#       From worker 5:	  (0, 18)	-0.03125
#       From worker 5:	  (0, 19)	-0.03125
#       From worker 5:	  (0, 20)	-0.03125
#       From worker 5:	  (0, 21)	-0.03125
#       From worker 5:	  (0, 22)	-0.03125
#       From worker 5:	  (0, 23)	-0.03125
#       From worker 5:	  (0, 24)	-0.03125
#       From worker 5:	  :	:
#       From worker 5:	  (996, 663)	-0.2
#       From worker 5:	  (996, 913)	-0.2
#       From worker 5:	  (996, 996)	1.0
#       From worker 5:	  (997, 88)	-0.14285714285714285
#       From worker 5:	  (997, 278)	-0.14285714285714285
#       From worker 5:	  (997, 452)	-0.14285714285714285
#       From worker 5:	  (997, 555)	-0.14285714285714285
#       From worker 5:	  (997, 625)	-0.14285714285714285
#       From worker 5:	  (997, 823)	-0.14285714285714285
#       From worker 5:	  (997, 828)	-0.14285714285714285
#       From worker 5:	  (997, 997)	1.0
#       From worker 5:	  (998, 343)	-0.2
#       From worker 5:	  (998, 759)	-0.2
#       From worker 5:	  (998, 839)	-0.2
#       From worker 5:	  (998, 872)	-0.2
#       From worker 5:	  (998, 946)	-0.2
#       From worker 5:	  (998, 998)	1.0
#       From worker 5:	  (999, 195)	-0.14285714285714285
#       From worker 5:	  (999, 260)	-0.14285714285714285
